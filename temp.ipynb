# %%
import os, glob

# %%
in_dir = '/media/trojan/evo/3D-CT-Artery-Segmentation/data/data_new/data_16_groups/train/images'
out_dir = '/media/trojan/evo/3D-CT-Artery-Segmentation/data/data_new/data_augmented/train/images'

# %%
_list = []
for img in os.listdir(out_dir):
    split1 = img.split('.')[0].split('_')[0]
    split2 = img.split('.')[0].split('_')[1]
    split = str(split1) + '_' + str(split2)
    _list.append(split)

_list = set(_list)
print(_list)
# Out:
# {'6_31', '2_43', '3_26', '3_24', '2_44', '27_17', '2_34', '4_25', '25_8', '27_32', '6_32', '20_38', '12_23', '28_2', '15_30', '23_9', '1_20', '12_30', '23_10', '27_30', '10_20', '2_33', '32_22', '11_24', '1_30', '21_9', '10_22', '32_18', '7_19', '4_23', '29_14', '34_4', '2_29', '6_44', '6_46', '3_48', '6_29', '19_3', '15_34', '3_44', '29_4', '31_4', '32_19', '6_36', '15_28', '4_46', '10_29', '27_31', '11_13', '25_3', '36_1', '3_37', '11_17', '4_38', '30_1', '27_24', '3_35', '20_28', '45_28', '27_34', '27_37', '28_3', '23_3', '14_27', '39_27', '21_2', '1_37', '11_25', '33_8', '20_29', '36_8', '4_37', '33_1', '20_20', '39_35', '20_31', '32_29', '1_22', '25_4', '41_4', '22_4', '19_4', '39_22', '6_34', '7_36', '3_46', '28_5', '10_34', '25_2', '45_40', '18_6', '39_20', '14_36', '21_4', '1_25', '27_25', '27_35', '10_24', '12_32', '12_27', '10_25', '1_34', '6_30', '32_35', '45_44', '11_40', '10_39', '1_19', '22_6', '45_29', '32_33', '4_42', '6_43', '40_4', '1_26', '41_3', '30_5', '37_4', '7
# ...

# %%
for img in os.listdir(in_dir):
    _str = img.split('.')[0]
    if _str not in _list:
        print(_str)
# Out:
# 8_32
# 9_17
# 8_15
# 8_16
# 8_17
# 8_18
# 8_19
# 8_20
# 8_21
# 8_22
# 8_23
# 8_24
# 8_25
# 8_26
# 8_27
# 8_28
# 8_29
# 8_30
# 8_31
# 8_33
# 8_34
# 8_35
# 8_36
# 8_37
# 8_38
# 8_39
# 8_40
# 8_41
# 8_42
# 8_43
# 8_7
# 8_8
# 9_18
# 9_19
# 9_20
# 9_21
# 9_22
# 9_23
# 9_24
# 9_30
# 9_31
# 9_32
# 9_33
# 9_34
# 9_35
# 9_36
# 9_37
# 9_38
